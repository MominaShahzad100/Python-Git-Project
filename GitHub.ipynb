# %% [markdown]
# <a href="https://colab.research.google.com/github/MominaShahzad100/Python-Git-Project/blob/main/GitHub.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# User se details lena
name = input("Enter your name: ")
age = int(input("Enter your age: "))

# Output print karna
print(f"Hello, {name}!")
print(f"Your age is: {age}")
print("Welcome to Google Colab and AI/ML Workflows!")
# Out:
# Enter your name: Momina Shahzad
# Enter your age: 24
# Hello, Momina Shahzad!
# Your age is: 24
# Welcome to Google Colab and AI/ML Workflows!

# %%
# Task 3 & 4 (Modified Version): Student & Project Info Entry

# User Inputs
student_name = input("Enter Student Name: ")
project_title = input("Enter Project Title: ")
num_datasets = int(input("Enter number of datasets collected: "))
avg_accuracy = float(input("Enter average model accuracy (%): "))

# Output Formatting
print("\n" + "="*40)
print("       AI/ML PROJECT SUMMARY REPORT       ")
print("="*40)
print(f" Student Name   : {student_name}")
print(f" Project Title  : {project_title}")
print(f" Datasets Count : {num_datasets}")
print(f" Model Accuracy : {avg_accuracy:.2f}%")
print(" Status         : Ready for Model Training!")
print("="*40)
# Out:
# Enter Student Name: Momina Shahzad
# Enter Project Title: Colab Pyton Project
# Enter number of datasets collected: 50
# Enter average model accuracy (%): 70
#
# ...
#        AI/ML PROJECT SUMMARY REPORT
# ...
#  Student Name   : Momina Shahzad
#  Project Title  : Colab Pyton Project
#  Datasets Count : 50
#  Model Accuracy : 70.00%
#  Status         : Ready for Model Training!
# ...
